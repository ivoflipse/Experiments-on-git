# %%
# %pylab inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
kronos = open("kronos.txt","r")
table = pd.read_table(kronos, header=0, sep="\t")
print table
# Out:
#   testType  Time  Value
# 0        A     1      1
# 1        B     2      2
# 2        C     3      3
# 3        B     4      2
# 4        C     5      3
# 5        A     6      1

# %%
A = pd.DataFrame(table[table.testType=="A"])
print A
B = pd.DataFrame(table[table.testType=="B"])
print B
C = pd.DataFrame(table[table.testType=="C"])
print C
# Out:
#   testType  Time  Value
# 0        A     1      1
# 5        A     6      1
#   testType  Time  Value
# 1        B     2      2
# 3        B     4      2
#   testType  Time  Value
# 2        C     3      3
# 4        C     5      3

# %%
fig, axes = plt.subplots(nrows=1)
p1, = axes.plot(A.Time, A.Value,'r-',label="A",lw=5)
p2, = axes.plot(B.Time, B.Value,'g-',label="B",lw=5)
p3, = axes.plot(C.Time, C.Value,'b-',label="C",lw=5)
axes.set_ylim([0, 5])
axes.legend()
